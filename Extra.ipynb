# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0,7,10,15,17,20])
y = np.array([0,250,75,175,75,300])

# %%
plt.plot(x,y, marker = "o", mec="b", ms=15, linestyle="dotted", color = "pink", linewidth = 4)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
